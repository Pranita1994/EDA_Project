# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranita1994/EDA_Project/blob/main/AirBnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AirBnb Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The "Airbnb Bookings Analysis" project is a comprehensive study aimed at providing valuable insights and understanding into the patterns and trends of Airbnb bookings in a particular city or region. Leveraging the vast dataset available from Airbnb's platform, this analysis will delve into various aspects of bookings, including user behavior, pricing dynamics, popular accommodations, and seasonal trends.
# The analysis will begin by collecting a large-scale dataset of Airbnb bookings, encompassing a sufficient timeframe to account for seasonal variations and long-term trends. By analyzing the data, we aim to uncover valuable information that can enhance decision-making for potential hosts and facilitate better planning for travelers looking to book accommodations through the platform.
# We will preprocess the data, cleaning it to remove any duplicates or errors and transforming it into a usable format. The data will then be subjected to exploratory data analysis (EDA) techniques, such as data visualization, to identify key patterns and trends in booking behavior.
#
# **Key Areas of Analysis:**
#
# **Booking Patterns**:
#
# Determine the most popular times for bookings throughout the year, including peak and off-peak seasons, and identify any significant changes over the years.
#
# **Price Dynamics**:
#
# Analyze the pricing strategies adopted by hosts and understand the impact of various factors on accommodation costs, such as location, amenities, and booking demand.
#
# **User Preferences**:
#
# Identify the most sought-after types of accommodations and amenities preferred by Airbnb users, enabling hosts to optimize their listings.
#
# **Geospatial Analysis**:
#
# Map the distribution of Airbnb listings geographically to visualize the concentration of accommodations in different areas.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Pranita1994/EDA_Project.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# We are going to explore the dataset to analye the given data and find some insights which we can call problems to be anlysed. Some of them are as follows:
#
#
# 1.   To determine the preference for private rooms over shared rooms or entire homes in Airbnb bookings, analyze the booking data from a selected city and identify the percentage distribution of bookings across these accommodation types.
# 2.   Investigate whether private rooms receive higher average ratings and better reviews from guests compared to shared rooms and entire homes, using sentiment analysis on user reviews from the Airbnb dataset.
# 3.   Conduct a geospatial analysis to map the concentration of private rooms, shared rooms, and entire homes across different neighborhoods in the city and assess if certain areas have a higher preference for specific accommodation types.
# 4.   Analyze the pricing dynamics of private rooms, shared rooms, and entire homes to determine if there is a significant price difference between these accommodation types and identify factors that influence their pricing variations.
# 5.   Conduct an analysis to investigate whether the Manhattan neighborhood is more preferred over other neighborhoods in the city for Airbnb bookings. Utilize the booking data to compare the demand, occupancy rates, and average rental prices of accommodations in Manhattan with those in other neighborhoods, aiming to identify any significant disparities in popularity.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **The business objectives of this project include:**
#
#
#
# 1.   **Accommodation Optimization**: Identify the most preferred types of accommodations (e.g., private rooms, shared rooms, entire homes) to help hosts tailor their listings according to the preferences of potential guests. This will allow hosts to maximize booking rates and occupancy.
# 2.  **Pricing Strategy Enhancement**: Analyze the pricing dynamics and factors influencing pricing variations for different accommodation types. This will enable hosts to set competitive prices that reflect the value of their listings and attract more bookings without compromising on profitability.
# 3.   **Location-based Decisions**: Evaluate the popularity and demand for accommodations in various neighborhoods, with a specific focus on comparing Manhattan to other areas. This information will guide hosts in making informed decisions about investing in properties or advertising in certain locations.
# 4.   **Competitive Insights**: Provide a competitive edge to hosts by understanding the preferences of competitors' guests and identifying gaps in the market. This will aid hosts in differentiating their listings and attracting more bookings.
# 5.   **Customer Experience Improvement**: This feedback will help hosts identify areas of improvement and enhance the overall guest experience.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib_inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Project/AirBnb_Booking_Analysis.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head() # It will show the first five rows of the dataset by default
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape  # df.shape will show the total count of rows and columns in the dataset
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Columns in the dataset
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Describe the dataset
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Dataset Info
df.info() # df.info() will show columns with name, their not-null count and datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# check null value count for each column
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### Duplicate Values

# %%
#  duplicated() function to identify duplicate rows in the DataFrame
#This function returns a boolean Series, where True indicates that the row is a duplicate.

duplicate_rows = df.duplicated()
duplicate_rows
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
# We can't conclude fully from True/False result for duplicate values.
# Dataset Duplicate Value Count
total_duplicates = duplicate_rows.sum()
total_duplicates
# Out:
# 0

# %% [markdown]
# The count result for duplicate values shows there is not even a single duplicate value in the dateset

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# check null value count for each column
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Some of the columns with null values are not necessory for analysis so we will drop these columns.
# Those which are useful, we will fill the null with values like 0.

# %%
# We drop unnecessary columns such as id, name, host_name, last_review.
df.drop(['name', 'host_name', 'last_review'], axis=1, inplace=True)
df.head()
# Out:
#      id  host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0  2539     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1  2595     2845           Manhattan       Midtown  40.75362  -73.98377
# 2  3647     4632           Manhattan        Harlem  40.80902  -73.94190
# 3  3831     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4  5022     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
# Though 'reviews_per_month' column is with 10052 Null values which is approx 20.55% of the total rows of this dataset column,
# we need 'reviews_per_month' column for overall monthly review so fill Null values with 0
df['reviews_per_month'].fillna(0, inplace = True)

# %%
# Visualizing the missing values
df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains essential details about the Airbnb listings, including their geographical locations, types of accommodations, pricing, availability, host information, and review statistics. This dataset can be used for various analyses, such as exploring popular neighborhoods, identifying room type preferences, analyzing pricing patterns, and understanding host behavior on the Airbnb platform.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
columns = df.columns
columns
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.090910
# std         20.510550          44.550582           1.597283
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **id**: This column contains a unique identifier for each Airbnb listing. It serves as a primary key to distinguish one listing from another.
#
# 2. **name**: This column contains the name or title of the Airbnb listing, which is typically provided by the host. It represents the name of the accommodation that guests can identify it by.
#
# 3. **host_id**: This column contains unique identifiers for the hosts who listed their properties on Airbnb. Each host has a distinct ID associated with their listings. It is used to link the host's information to the respective listings.
#
# 4. **host_name**: This column stores the name of the host who owns or manages the listing. It represents the name of the individual responsible for the property.
#
# 5. **neighbourhood_group**: This column represents the broader geographical divisions or boroughs in which the accommodations are located. Examples of neighbourhood groups could be "Manhattan," "Brooklyn," "Queens," etc. It helps in understanding the general area where the listing is situated.
#
# 6. **neighbourhood**: This column provides the specific neighborhoods within the neighbourhood groups where the Airbnb accommodations are situated. Examples of neighbourhoods could be "Chelsea," "Williamsburg," "Astoria," etc. It gives more specific location information within a neighbourhood group.
#
# 7. **latitude**: This column contains the latitude coordinates of the Airbnb listings, representing their geographical position on the Earth's surface. Latitude values indicate the north-south position.
#
# 8. **longitude**: This column contains the longitude coordinates of the Airbnb listings, representing their geographical position on the Earth's surface. Longitude values indicate the east-west position.
#
# 9. **room_type**: This column indicates the type of room being listed, such as "Private room," "Entire home/apt," or "Shared room." It defines the type of accommodation being offered to guests.
#
# 10. **price**: This column represents the price per night for booking the accommodation. It shows the cost that guests need to pay to stay at the listing for one night.
#
# 11. **minimum_nights**: This column denotes the minimum number of nights required for booking the accommodation. It indicates the minimum length of stay set by the host.
#
# 12. **number_of_reviews**: This column shows the total number of reviews received for the listing. It reflects the overall feedback from guests who have stayed at the property and provided reviews.
#
# 13. **last_review**: This column contains the date of the last review received for the listing. It provides information about the most recent review left by a guest.
#
# 14. **reviews_per_month**: This column calculates the average number of reviews received per month. It offers insights into the rate at which guests are providing feedback for the listing.
#
# 15. **calculated_host_listings_count**: This column indicates the total number of listings managed by each host. It gives an idea of the host's activity level on the platform.
#
# 16. **availability_365**: This column represents the number of days the accommodation is available for booking in a year (out of 365 days). It shows the extent of the property's availability throughout the year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  reviews_per_month is 938 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
#  The price for any type of room can't be 0 which is impossible and it will affect the room mean price analysis in future. So there are two ways to solve this problem either we check the dataset to collect rows with price 0 and delete that rows or we can set that price to sum minimum value price. For this we have to do data wrangling on price column.

# %%
df[df['price']==0]
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 23161  18750597    8993084            Brooklyn  Bedford-Stuyvesant  40.69023
# 25433  20333471  131697576               Bronx     East Morrisania  40.83296
# 25634  20523843   15787004            Brooklyn            Bushwick  40.69467
# 25753  20608117    1641537            Brooklyn          Greenpoint  40.72462
# 25778  20624541   10132166            Brooklyn        Williamsburg  40.70838
# 25794  20639628   86327101            Brooklyn  Bedford-Stuyvesant  40.68173
# 25795  20639792   86327101            Brooklyn  Bedford-Stuyvesant  40.68279
# 25796  20639914   86327101            Brooklyn  Bedford-Stuyvesant  40.68258
# 26259  20933849   13709292           Manhattan         Murray Hill  40.75091
# 26841  21291569  101970559            Brooklyn            Bushwick  40.69211
# 26866  21304320  101970559            Brooklyn            Bushwick  40.69166
#
# ...

# %%
zero_price_count = (df['price']==0).value_counts()
zero_price_count
# Out:
# False    48884
# True        11
# Name: price, dtype: int64

# %% [markdown]
# <h5> This value count result shows that total 11 rows in the price column are with price value 0 and 48884 are with value greater than 0. This result is out of 48895 rows which is approx. 0.02249 %.
# <p> Either of these price value can be mistype or NaN that is null. So it is better to drop these rows to minimize the future effect on the dataset

# %%
# Drop the rows which has price value 0
df.drop(df[df['price'] == 0].index, inplace=True)

# %%
# Check for price value = 0
zero_price_count = (df['price']==0).value_counts()
zero_price_count
# Out:
# False    48884
# Name: price, dtype: int64

# %%
df['price'].describe()
# Out:
# count    48884.000000
# mean       152.755053
# std        240.170260
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ####<h3> Chart 1 - Box plot of Price

# %%
# We create a box plot to visualize the distribution of prices.
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['price'])
plt.title('Box Plot of Price')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are helpful for visualizing the distribution and identifying potential outliers in the data,showing the distribution of prices, including any outliers that may exist.Create a box plot to visualize the distribution of prices. Box plots display the median, quartiles, and potential outliers. If you observe points beyond the whiskers, those might indicate outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The insight found from this indicates that there are many data points in that column that deviate significantly from the rest of the data. The length of the box (interquartile range) indicates the spread of prices between the 25th and 75th percentiles. A smaller box indicates a more concentrated price distribution. utliers represent data points that significantly deviate from the majority of the prices. They could indicate unusual or exceptional listings with either very high or very low prices.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the box plot can indeed help create a positive business impact if analyzed and acted upon correctly.
#
# *  Understanding the central tendency of prices can help identify market trends, such as the average price customers are willing to pay for accommodations. This insight allows businesses to set competitive prices that attract customers while maximizing revenue.
# *   Analyzing the spread and variability of prices helps businesses optimize revenue. By understanding the range of prices that customers are willing to pay, businesses can tailor pricing strategies to capture different segments of the market and maximize revenue.
# *  Examining outliers can reveal valuable information about unique and exceptional listings. Businesses can investigate the reasons behind exceptionally high or low prices and leverage this knowledge to offer premium services or address issues that may be affecting customer satisfaction.
#
# The box plot has many outliers and the box itself is smaller, it could potentially indicate some negative growth prospects:
#
# *   Price Disparities: A large number of outliers suggest significant price disparities in the market, which may lead to an uneven distribution of customers. Extreme outliers with very high prices might deter budget-conscious customers, while very low outliers might raise concerns about the quality of accommodations.
# *   Market Segmentation Challenges: A small box and numerous outliers could signify that the market is highly fragmented with listings scattered across a wide price range. This could lead to difficulties in targeting specific customer segments effectively and may result in lost opportunities for growth and customer retention.

# %% [markdown]
# ####<h3>Chart 2 - Histogram of Price</h3>

# %%
# Plot histogram to visualize the distribution of prices
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True)
plt.title('Histogram of Price')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms are used to visualize the distribution of a continuous numerical variable, such as the "price" column in this dataset. They provide a way to understand the underlying frequency distribution of the data, allowing us to see how the values are spread across different ranges or bins.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram plot of prices shows the distribution of a continuous numerical variable between 10 to 2000, even though the actual price range is from 10 to 10000, there could be several insights that can be derived from the chart:
#
#
# *  The histogram reveals the concentration of prices within the range of 10 to 2000. If the majority of prices are clustered in this range, it indicates that most listings fall within this price bracket.
# * As the histogram shows a right-skewed distribution, it means there are relatively more listings with lower prices (closer to 10) and fewer listings with higher prices (closer to 2000). This could indicate that the market is more budget-oriented, with a higher demand for affordable accommodations.
# *  If there are clear peaks at specific price points, it indicates that those price points are attractive to customers and might represent pricing sweet spots.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the histogram plot can indeed help create a positive business impact if utilized effectively. However, there are also potential insights that could lead to negative growth if not appropriately addressed.
# *  Understanding the distribution of prices can help businesses optimize their pricing strategies. They can identify popular price ranges and adjust their pricing to align with customer preferences, increasing the likelihood of attracting more bookings.
# *   Analyzing demand patterns at different price points enables businesses to implement dynamic pricing strategies. They can adjust prices based on factors such as seasonality, demand fluctuations, and special events to optimize revenue.

# %% [markdown]
# ####<h3>1.  Calculate unique room_type in Neighbourhood Group and types of room and their total count</h3>

# %%
room_type = df['room_type'].unique()
neighbourhood_group = df['neighbourhood_group'].unique()
print(f"The room types are {room_type} in the following neighbourhood groups : {neighbourhood_group}")
room_areawise = df.groupby(['neighbourhood_group'])['room_type'].count().reset_index()
room_areawise.sort_values(by='room_type', ascending = False).head()
# Out:
# The room types are ['Private room' 'Entire home/apt' 'Shared room'] in the following neighbourhood groups : ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
#   neighbourhood_group  room_type
# 2           Manhattan      21660
# 1            Brooklyn      20095
# 3              Queens       5666
# 0               Bronx       1090
# 4       Staten Island        373

# %%
room_count = df['room_type'].value_counts()
room_count
# Out:
# Entire home/apt    25407
# Private room       22319
# Shared room         1158
# Name: room_type, dtype: int64

# %% [markdown]
# ####<h3>Chart 3 - Bar chart on types of rooms and their total count </h3>

# %%
# Visualize the data
plt.figure(figsize=(10,5))
plt.title("Room Types count")
df['room_type'].value_counts().plot(kind = 'bar', color = ['blue','green','red'])
plt.xlabel('room_type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the bar chart to represent the types of rooms and their total count because it effectively displays the categorical data with discrete values. The bar chart allows for easy comparison between different room types and their respective counts. It provides a clear visual representation of the distribution of room types and allows viewers to quickly grasp the relative proportions of each category.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, the following insights can be derived:
#
# *  The most common room type is "Entire home/apt" with 25407 counts, indicating a high demand for entire homes or apartments as accommodations.
# *  The second most common room type is "Private room" with 22319 counts . While not as prevalent as "Entire home/apt," private rooms are still in substantial demand.
# *  The least common room type is "Shared room" with 1158 counts, indicating limited interest in shared accommodations. Moreover, the count for shared rooms is closer to 0, suggesting a relatively low demand for this room type.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the bar chart can help create a positive business impact in the following ways:
#
# *   The high demand for "Entire home/apt" and "Private room" suggests that focusing on these room types can lead to increased bookings and revenue. Businesses can allocate resources to enhance and market these types of accommodations.
# *  By understanding the popularity of different room types, businesses can tailor their offerings to align with customer preferences. They can optimize the mix of room types available in their portfolio to attract a diverse range of customers.
# *  The insights can also inform pricing strategies. Knowing which room types are in higher demand can help businesses set competitive prices and maximize revenue from their listings.
# *   The data can guide promotional efforts, with a focus on highlighting the most popular room types to attract potential guests and improve booking rates.
#
#
# Insights that lead to negative growth:
# The insight that "Shared room" has the least count indicates a lack of demand for this room type. If a business heavily invests in offering shared rooms without considering the low demand, it could lead to negative growth. Resources spent on promoting or expanding shared accommodations might not yield sufficient returns, resulting in lower occupancy rates and potentially impacting overall profitability.
#
# To avoid negative growth, businesses should carefully evaluate the demand for each room type and align their offerings with market preferences. It may be more beneficial to focus on the higher-demand room types, "Entire home/apt" and "Private room," which are likely to drive positive business outcomes. Additionally, continuous monitoring of market trends and customer preferences is essential to stay agile and adapt to changing demands in the hospitality industry.

# %% [markdown]
# <h3>2. Neighbourhood Group based on latitude and longitude</h3>

# %% [markdown]
# ####<h3>Chart 4 - Scatter plot on Neighbourhood Group based on latitude and longitude </h3>

# %%
#Neighbourhood Group based on latitude and longitude
plt.figure(figsize = (12,6))
plt.title("Neighbourhood group map")
sns.scatterplot(x = df.latitude, y = df.longitude, hue = df.neighbourhood_group)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot is chosen to represent the relationship between the Neighbourhood Group and its geographical location (latitude and longitude). Scatter plots are suitable for visualizing the distribution of two continuous variables, making them ideal for displaying geographical data. The points in the scatter plot represent the individual data points (Neighbourhood Groups) and their corresponding latitude and longitude values, providing an intuitive representation of the data's spatial distribution.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In this scatter plot, each point represents a location based on its latitude and longitude, and the color of the point corresponds to its assigned neighborhood group. The color bar on the side of the plot helps to interpret the neighborhood group mappings.
#
# The scatter plot can provide several insights:
#
#
# *  Clustering: The scatter plot can reveal patterns of clustering among Neighbourhood Groups. Groups located closer together may form clusters that represent specific areas or regions.The clusters are neighbourhood groups here.
# *   Geographical Distribution: The plot visually depicts how different Neighbourhood Groups are distributed across the geographic area represented by latitude and longitude values.'Brooklyn', 'Manhattan', 'Queens','Bronx' are closer to each other according to geographical distribution. While,  'Staten Island' is situated in the lower region and somewhat distant from others.
# *  Outliers: Outliers in the plot could indicate Neighbourhood Groups that are geographically distant from other groups, potentially representing unique or remote areas.  'Staten Island' has distict point in some part and some are in closer form. But, it is hard to count them as outliers as they are in its region group itself. While 'Queens' has some outlier in the top left part of the region. They are distinct from other groups and 'Queens' group too.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the scatter plot can potentially create a positive business impact:
#
# *  Targeted Marketing: Understanding the geographical distribution of Neighbourhood Groups can help businesses target their marketing efforts more effectively. They can tailor marketing campaigns to specific geographic areas and cater to the preferences of residents and tourists in those regions.
#
# *   Resource Allocation: Businesses can allocate resources, such as customer support and property management, based on the concentration and clustering of Neighbourhood Groups. This optimization can improve customer service and operational efficiency.
#
# *  Market Segmentation: The scatter plot can help identify different segments of the market based on geographic locations. Businesses can customize their offerings to cater to the needs and preferences of customers in each segment.
#
# While the scatter plot itself might not directly lead to negative growth, there are potential challenges that businesses should consider when using this visualization:
#
# *  Competition: Areas with a high concentration of listings (dense clusters) might lead to increased competition, which could result in price wars and reduced profitability for individual properties.
#
# *   Seasonality: The geographical distribution may reveal seasonal variations in demand for different Neighbourhood Groups. Businesses need to adapt their strategies to accommodate these fluctuations.
#
# *  Market Saturation: If the plot shows a high density of listings in certain areas, it might indicate market saturation in those regions. This could make it challenging for new entrants to gain a foothold and lead to more intense competition.

# %% [markdown]
# ####<h3>Chart 5 - Bar chart on Neighbourhood groups and their total listings count </h3>

# %%
# Neighbourhood groups and their total count
neighbourhood_group_count = df['neighbourhood_group'].value_counts()
neighbourhood_group_count
# Out:
# Manhattan        21660
# Brooklyn         20095
# Queens            5666
# Bronx             1090
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
# Visualize Neighbourhood group data
plt.figure(figsize=(10,5))
plt.title("Neighbourhood Group")
df['neighbourhood_group'].value_counts().plot(kind = 'bar', color = ['blue','green','red','yellow','brown'])
plt.xlabel('Total listing counts in Neighbourhood Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the total count of each Neighbourhood Group. A bar chart is an appropriate choice because it effectively visualizes categorical data, such as Neighbourhood Groups, and their corresponding counts. The chart uses rectangular bars to represent each group's count, making it easy to compare the values and identify patterns.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, the following insights can be derived:
#
#
# *   Manhattan has the highest count of listings with 21,660, making it the most popular neighbourhood group for Airbnb listings among the provided data.
# *   Brooklyn is the second most popular neighbourhood group with 20,095 listings, indicating a significant number of available properties.
# *   Queens has a count of 5,666 listings, making it the third most popular neighbourhood group, but its count is notably lower than Manhattan and Brooklyn.
# *   Bronx and Staten Island have lower counts compared to the other boroughs, with 1,090 and 373 listings, respectively.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart can help create a positive business impact:
#
# *   Market Focus: Understanding the popularity of each neighbourhood group can guide businesses to focus on areas with higher demand. They can prioritize resources for property management, customer service, and marketing efforts in areas like Manhattan and Brooklyn where demand is high.
#
# *  Competitive Strategies: Knowing the popularity of different neighbourhood groups allows businesses to tailor their competitive strategies. For example, in highly competitive areas like Manhattan, businesses may need to offer unique selling points or competitive pricing to stand out.
#
#
# While the bar chart itself may not directly lead to negative growth, certain insights should be taken into consideration to avoid potential pitfalls:
#
# *   Saturation Risk: In neighbourhood groups with high counts, such as Manhattan and Brooklyn, there might be higher market saturation, leading to more intense competition among hosts. This could potentially impact profit margins.
#
# *   Market Concentration: Relying too heavily on a single popular neighbourhood group could make the business vulnerable to fluctuations in that specific market. Changes in demand or regulatory issues in the area might negatively affect the business's revenue if it's overly reliant on one region.

# %% [markdown]
# ####<h3>Chart 6 - Pie chart of Percentwise visualization of Neighbourhood Group</h3>

# %%
# Calculate the total count of listings
total_listings = len(df)

# Use groupby() to get the count of each Neighbourhood Group
neighbourhood_group_counts = df['neighbourhood_group'].value_counts()

# Calculate the percentage for each Neighbourhood Group
percentages = (neighbourhood_group_counts / total_listings) * 100
percentages
# Out:
# Manhattan        44.308976
# Brooklyn         41.107520
# Queens           11.590705
# Bronx             2.229768
# Staten Island     0.763031
# Name: neighbourhood_group, dtype: float64

# %%
# Percentwise visualization of Neighbourhood Group
plt.figure(figsize=(12,6))
plt.title('Percentwise visualization of Neighbourhood Group')
plt.pie(df['neighbourhood_group'].value_counts(),startangle=180, labels = df['neighbourhood_group'].value_counts().index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a pie chart representing the percentage distribution of Neighbourhood Groups. A pie chart is suitable for visualizing relative proportions or percentages of different categories. In this case, the pie chart effectively displays the percentage distribution of each Neighbourhood Group, making it easy to compare the popularity of different groups at a glance.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pie chart, the following insights can be derived:
#
# *   Manhattan and Brooklyn are the most popular Neighbourhood Groups, accounting for approximately 44.3% and 41.1% of the total listings, respectively. These two boroughs have a significant share of the market and are in high demand among Airbnb guests.
#
# *   Queens has a moderate share of approximately 11.6% of the total listings, indicating it is a popular choice among visitors but not as dominant as Manhattan and Brooklyn.
#
# *   Bronx and Staten Island have relatively smaller shares of approximately 2.2% and 0.8%, respectively. These boroughs have lower popularity compared to the other three, suggesting that they might attract fewer Airbnb guests.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart can help create a positive business impact:
#
# *   Market Focus: Understanding the popularity of each neighbourhood group can guide businesses to focus on areas with higher demand. They can prioritize resources for property management, customer service, and marketing efforts in areas like Manhattan and Brooklyn where demand is high.
#
# *  Competitive Strategies: Knowing the popularity of different neighbourhood groups allows businesses to tailor their competitive strategies. For example, in highly competitive areas like Manhattan, businesses may need to offer unique selling points or competitive pricing to stand out.
#
#
# While the bar chart itself may not directly lead to negative growth, certain insights should be taken into consideration to avoid potential pitfalls:
#
# *   Saturation Risk: In neighbourhood groups with high counts, such as Manhattan and Brooklyn, there might be higher market saturation, leading to more intense competition among hosts. This could potentially impact profit margins.
#
# *   Market Concentration: Relying too heavily on a single popular neighbourhood group could make the business vulnerable to fluctuations in that specific market. Changes in demand or regulatory issues in the area might negatively affect the business's revenue if it's overly reliant on one region.

# %% [markdown]
# ####<h3>3. Room type with their prices in that particular area.</h3>

# %%
room_price_area = df.groupby(['room_type', 'neighbourhood_group'])['price'].max().reset_index()
room_price_area_sorted = room_price_area.sort_values(by = 'price', ascending = False)
room_price_area_sorted
# Out:
#           room_type neighbourhood_group  price
# 1   Entire home/apt            Brooklyn  10000
# 2   Entire home/apt           Manhattan  10000
# 8      Private room              Queens  10000
# 7      Private room           Manhattan   9999
# 6      Private room            Brooklyn   7500
# 4   Entire home/apt       Staten Island   5000
# 3   Entire home/apt              Queens   2600
# 5      Private room               Bronx   2500
# 13      Shared room              Queens   1800
# 0   Entire home/apt               Bronx   1000
# 12      Shared room           Manhattan   1000
# 10      Shared room               Bronx    800
# 11      Shared room            Brooklyn    725
# 9      Private room       Staten Island    300
# 14      Shared room       Staten Island    150

# %% [markdown]
# ####<h3>Chart 7 - Bar chart on Room Types with Their Highest Price in Each Neighborhood Group </h3>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='neighbourhood_group', y='price', hue='room_type', data=room_price_area_sorted)
plt.title('Room Type with Their Highest Price in Each Neighborhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')
plt.legend(title='Room Type', loc='upper right')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the highest price of each room type in each Neighbourhood Group. A bar chart is appropriate for visualizing and comparing numerical data, such as prices, across different categories. It allows for easy identification of the highest prices for each room type in each Neighbourhood Group.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, the following insights can be derived:
#
# *  The most expensive listings in both Brooklyn and Manhattan are "Entire home/apt" type, with a price of 10,000. These two Neighbourhood Groups have premium offerings for entire homes or apartments.
#
# *   Queens has the most expensive "Private room" listing, also priced at 10,000. This suggests that there might be luxury private rooms available in Queens.
#
# *   The highest-priced "Private room" in Manhattan is 9,999, indicating  that luxury private accommodations are available in this prime location as well.
# *  The most expensive "Private room" in Brooklyn is 7,500, suggesting that there are upscale private room options in this popular borough.
#
# *   Staten Island's highest-priced listings are "Entire home/apt" and "Private room," both priced at 5,000 and 300, respectively. This shows a contrast between the highest-priced offerings in Staten Island compared to the other boroughs.
#
# *  The highest-priced "Entire home/apt" in Queens is 2,600, indicating that Queens offers a range of entire home accommodations at more affordable prices.
#
#
# *   In the Bronx, the most expensive listings are "Entire home/apt" and "Private room," priced at 1,000 and 2,500, respectively. This suggests a variety of accommodation options available at different price points in the borough.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart can help create a positive business impact:
#
#
#
# *   Pricing Strategy: Understanding the highest prices for each room type in each Neighbourhood Group can inform pricing strategies. Businesses can adjust their prices based on the market demand and offer competitive rates for different types of accommodations.
#
# *   Targeted Marketing: Knowledge of the highest-priced listings in each Neighbourhood Group allows businesses to target specific customer segments seeking luxury or high-end accommodations.
#
#
#
# *   Product Differentiation: The insights help businesses differentiate their offerings based on room types and price points. They can emphasize unique features or amenities to attract customers looking for specific types of accommodations.
#
# While the bar chart itself may not directly lead to negative growth, businesses should consider the following potential challenges:
#
#
#
# *   Competitive Pressure: Offering the highest-priced listings might lead to increased competition. If a business cannot deliver the expected level of quality or unique features for these premium listings, it could result in negative customer reviews and reduced bookings.
# *   Limited Demand: Very high-priced listings may have limited demand, as they cater to a niche market of luxury travelers. Relying solely on such offerings might limit the business's overall customer base and growth potential.

# %% [markdown]
# ####<h3> 4.  Average Price for rooms in neighbourhood group</h3>

# %%
mean_price = df.groupby(['room_type','neighbourhood_group'])['price'].mean()
mean_price_sorted = pd.DataFrame(mean_price).sort_values(by ='room_type', ascending=True)
mean_price_sorted
# Out:
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Bronx                127.506596
#                 Brooklyn             178.346202
#                 Manhattan            249.257994
#                 Queens               147.050573
#                 Staten Island        173.846591
# Private room    Bronx                 66.890937
#                 Brooklyn              76.545428
#                 Manhattan            116.776622
#                 Queens                71.762456
#                 Staten Island         62.292553
# Shared room     Bronx                 59.800000
#                 Brooklyn              50.773723
#                 Manhattan             88.977083
#                 Queens                69.020202
#                 Staten Island         57.444444

# %% [markdown]
# ####<h3>Chart 8 - Bar chart on Average Price for rooms in neighbourhood group with error bars </h3>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=df['neighbourhood_group'], y=df['price'], hue=df['room_type'], data= pd.DataFrame(mean_price),palette='bright')
plt.title('Mean Room Price by Room Type and Neighborhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Mean Price')
plt.legend(title='Room Type', loc='upper right')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart with error bars representing the average price for each room type in each Neighbourhood Group. A bar chart with error bars is suitable for comparing average values (prices) across different categories (Neighbourhood Groups) and displaying the variability (standard deviation or confidence interval) of the data. The error bars provide an indication of the uncertainty around the average price, making it a comprehensive and informative visualization.
#
# Error Bars help to indicate estimated error or uncertainty to give a general sense of how precise a measurement is. This is done through the use of markers drawn over the original graph and its data points.The bar heights represent their mean value. The black error bar gives information on how the individual observations are dispersed around the average. Error bars give a general idea of how precise a measurement is, or conversely, how far from the reported value the true (error free) value might be. If the value displayed on your barplot is the result of an aggregation (like the mean value of several data points), you may want to display error bars.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart with error bars, the following insights can be derived:
#
# *  Manhattan has the highest average prices across all room types, indicating that it is generally the most expensive Neighbourhood Group for accommodations.
#
# *   Brooklyn and Staten Island have relatively lower average prices compared to Manhattan but still offer a range of price points for different room types.
#
# *   Queens and the Bronx have the lowest average prices, suggesting that they might be more budget-friendly options for travelers.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart with error bars can help create a positive business impact:
#
# *   Pricing Strategies: Understanding the average prices in each Neighbourhood Group allows businesses to develop competitive pricing strategies. They can adjust their rates to align with the market and attract customers seeking different price ranges.
#
# *   Market Positioning: Businesses can use this information to position themselves strategically within the market. For example, they can emphasize affordability in Queens and the Bronx or target luxury travelers in Manhattan.
#
# *  Marketing and Promotions: Knowledge of the average prices can guide marketing efforts and promotions. Businesses can use this data to promote specific Neighbourhood Groups or room types that offer the best value for money.
#
#
# While the bar chart with error bars itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
#
# *   Overpriced Listings: If the average prices are significantly higher than what customers perceive as reasonable, it may lead to decreased bookings and negative reviews. It's essential for businesses to justify higher prices with exceptional quality and amenities.
#
# *  Underpriced Listings: Underpriced accommodations might attract bookings but could result in missed revenue opportunities. Businesses should ensure their pricing aligns with the value they provide to customers.

# %% [markdown]
# ####<h3>Chart 9 - Bar chart on Average Price for rooms in neighbourhood group without error bars </h3>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=df['neighbourhood_group'], y=df['price'], hue=df['room_type'], data= pd.DataFrame(mean_price),palette='bright',ci = None)
plt.title('Mean Room Price by Room Type and Neighborhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Mean Price')
plt.legend(title='Room Type', loc='upper right')
plt.show()
# Out:
# <ipython-input-40-da94607f541b>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['neighbourhood_group'], y=df['price'], hue=df['room_type'], data= pd.DataFrame(mean_price),palette='bright',ci = None)

# %% [markdown]
# ####<h3>Chart 10 - Horizontal Bar chart on Mean price by room types </h3>

# %%
mean_price_sorted = mean_price.sort_values(ascending=True).reset_index()
mean_price_sorted
# Out:
#           room_type neighbourhood_group       price
# 0       Shared room            Brooklyn   50.773723
# 1       Shared room       Staten Island   57.444444
# 2       Shared room               Bronx   59.800000
# 3      Private room       Staten Island   62.292553
# 4      Private room               Bronx   66.890937
# 5       Shared room              Queens   69.020202
# 6      Private room              Queens   71.762456
# 7      Private room            Brooklyn   76.545428
# 8       Shared room           Manhattan   88.977083
# 9      Private room           Manhattan  116.776622
# 10  Entire home/apt               Bronx  127.506596
# 11  Entire home/apt              Queens  147.050573
# 12  Entire home/apt       Staten Island  173.846591
# 13  Entire home/apt            Brooklyn  178.346202
# 14  Entire home/apt           Manhattan  249.257994

# %%
mean_price_sorted = mean_price.sort_values(ascending=True)
mean_price_sorted.plot(kind='barh')

plt.title('Mean Price by Room Type')
plt.xlabel('Mean Price')
plt.ylabel('Room Type')

plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a horizontal bar chart representing the mean price for each room type in different Neighbourhood Groups. A horizontal bar chart is ideal for comparing numerical data (mean prices) across different categories (room types) with longer labels. It allows for clear visualization and easy comparison of the average prices within each room type, making it an effective and informative chart.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the horizontal bar chart, the following insights can be derived:
#
#
# *   Among all room types, "Entire home/apt" in Manhattan has the highest mean price, indicating that this type of accommodation is generally the most expensive in Manhattan.
#
# *   "Entire home/apt" listings in Brooklyn, Staten Island, and Queens also have relatively high mean prices, suggesting a consistent demand for entire homes or apartments across multiple boroughs.
#
# *   "Private room" listings have a moderate range of mean prices across all boroughs, with Manhattan having the highest mean price and the Bronx the lowest.
#
# *  "Shared room" listings generally have the lowest mean prices, with Brooklyn having the lowest mean price among all boroughs.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the horizontal bar chart can help create a positive business impact:
#
# *   Pricing Strategies: Understanding the mean prices for each room type in different Neighbourhood Groups allows businesses to develop competitive and targeted pricing strategies. They can adjust their rates based on customer preferences and market demand.
#
# *  Market Segmentation: Businesses can use this information to segment their target audience based on price preferences. They can offer affordable options for budget-conscious travelers and luxury options for those willing to pay more.
#
# *  Revenue Optimization: Knowing which room types have higher mean prices allows businesses to prioritize resources and marketing efforts on more profitable listings.
#
# While the horizontal bar chart itself may not directly lead to negative growth, businesses should consider the following potential challenges:
#
#
#
# *   Price Sensitivity: If the mean prices are higher than what customers are willing to pay or perceive as reasonable, it may lead to reduced bookings and potential negative reviews. Price sensitivity analysis is crucial to avoid overpricing.
#
# *  Competition: Highly competitive markets might lead to pressure on businesses to keep prices low, affecting revenue and profitability.

# %% [markdown]
# ####<h3>5. Price Variation Within Room Types</h3>

# %%
# Calculate the standard deviation of price for each room type
room_type_std = df.groupby('room_type')['price'].std()
room_type_std
# Out:
# room_type
# Entire home/apt    284.046575
# Private room       160.222493
# Shared room        101.771306
# Name: price, dtype: float64

# %% [markdown]
# ####<h3> Chart 11 - Box plot for Price Variation Within Room Types </h3>

# %%
# Creating a box plot for each room type
plt.figure(figsize=(10, 6))
plt.boxplot([df[df['room_type'] == room]['price'] for room in df['room_type'].unique()], labels=df['room_type'].unique())
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.title('Price Variation Within Room Types')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a box plot representing the price variation within each room type. A box plot is ideal for visualizing the distribution of numerical data, particularly when comparing multiple groups or categories. It provides information about the central tendency, variability, and presence of outliers within each room type, making it an effective chart to analyze price distribution.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot, the following insights can be derived:
#
#
#
# *   The "Entire home/apt" room type has the highest median price at 284.05, indicating that, on average, entire homes or apartments are the most expensive listings among the three room types.
#
# *   The "Private room" category has a lower median price compared to "Entire home/apt," indicating that private rooms are generally more affordable for guests.
#
# *   The "Shared room" category has the lowest median price at 101.77, suggesting that it offers the most budget-friendly accommodation option among the three room types.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the box plot can help create a positive business impact:
#
#
# * Pricing Strategies: Understanding the price variation within each room type enables businesses to develop effective pricing strategies. They can set competitive prices for different room types to attract various customer segments.
#
# *  Marketing and Promotion: The insights can be used in marketing efforts to target customers seeking specific price ranges. For example, businesses can highlight the affordability of shared rooms or the luxury of entire homes to attract different types of travelers.
#
# *   Revenue Optimization: Businesses can optimize revenue by adjusting prices based on the demand for each room type. During peak seasons or high-demand periods, prices for "Entire home/apt" listings might be adjusted to maximize revenue.
#
# While the box plot itself may not directly lead to negative growth, businesses should consider the following potential challenges:
#
#
#
# *  Competitive Pricing: If prices within a particular room type are significantly higher than competitors or customer expectations, it may lead to reduced bookings and negative reviews. It's essential to maintain a competitive edge with reasonable prices.
#
# *   Seasonal Variation: Price variation may fluctuate seasonally or due to changes in demand. Businesses should be prepared to adjust their pricing strategies to adapt to changing market conditions.

# %% [markdown]
# ####<h3>6. Relationship between the availability room and neighborhood group</h3>

# %% [markdown]
# ####<h3> Chart 12 - Box plot on Relationship between the availability of rooms and neighborhood group </h3>

# %%
plt.style.use('classic')
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['neighbourhood_group'], y=df['availability_365'],
            palette='colorblind')
plt.title('Relationship between the availability of rooms and neighborhood group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Available rooms')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a box plot representing the relationship between the availability of rooms and Neighbourhood Groups. A box plot is suitable for visualizing the distribution of a numerical variable (availability) within different categories (Neighbourhood Groups). It provides information about the central tendency, variability, and presence of outliers in the availability data for each group, making it an effective chart for analyzing the relationship between these variables.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot, the following insights can be derived:
#
#
#
#
#
# *   The box plot will show the distribution of room availability for each Neighbourhood Group. The central box represents the interquartile range (IQR), indicating where the middle 50% of the data falls.
#
# *   The median value within each box represents the middle value of the availability data for each Neighbourhood Group.
#
# *  The whiskers extending from the box indicate the range of the data, excluding outliers. Outliers, if present, are represented as individual data points beyond the whiskers.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the box plot can help create a positive business impact:
#
#
#
# *  Demand Analysis: Understanding the availability distribution across different Neighbourhood Groups can help businesses identify areas with higher demand and popularity. This can guide resource allocation and marketing efforts to capitalize on areas where there is more potential for bookings.
#
# *  Pricing and Inventory Management: Businesses can use the insights to adjust their pricing strategies based on demand and availability. In areas with high availability and lower demand, businesses might consider offering promotions or discounts to attract more bookings. In contrast, in areas with limited availability and high demand, businesses can adjust prices to optimize revenue.
#
# *   Competitive Positioning: The availability data can also provide insights into the competitive landscape. By comparing availability across different Neighbourhood Groups, businesses can identify areas where they have a competitive advantage or areas where they need to improve their offerings to attract more guests.
#
# While the box plot itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
#
# *   Seasonal Variation: Availability of rooms might vary seasonally. Businesses should be prepared to adjust their strategies during peak and off-peak seasons to optimize occupancy rates and revenue.
#
# *   Oversaturation: In areas with high availability and low demand, businesses might face higher competition, which could lead to price wars and reduced profitability.

# %% [markdown]
# ####<h3> 7. Review count according to area

# %%
area_reviews = df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
area_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %% [markdown]
# <h4> Neighbourhood Group 'Queens' has most number of review count while, neighbourhood Group 'Bronx' has the least number of reviews</h4>

# %%
area_review_count = df.groupby(['neighbourhood'])['number_of_reviews'].max().reset_index()
review_neighbour = area_review_count.sort_values(by = 'number_of_reviews',ascending = False)
review_neighbour
# Out:
#                   neighbourhood  number_of_reviews
# 105                     Jamaica                629
# 94                       Harlem                607
# 59                East Elmhurst                543
# 119             Lower East Side                540
# 151                  Park Slope                488
# ..                          ...                ...
# 148                     Oakwood                  4
# 9    Bay Terrace, Staten Island                  2
# 82               Fort Wadsworth                  0
# 141                    New Dorp                  0
# 219                     Woodrow                  0
#
# [221 rows x 2 columns]

# %% [markdown]
# <h4> By Analysing the count of reviews from 221 rows which shows the neighbors that is places in the neighbourhood group, Jamaica is on the top with 629 reviews and Fort Wadsworth, New Dorp, Woodrow are the places with 0 count of reviews.</h4>

# %% [markdown]
# ####<h3> Chart 13 - Bar charts to show Review count according to neighbouring group and Neighbourhood </h3>

# %%
top_5_neighbourhoods = review_neighbour.head(5)

plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.title('Review count according to neighbouring group')
plt.bar(area_reviews['neighbourhood_group'],area_reviews['number_of_reviews'], color = 'darkviolet')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Total no. of reviews')

plt.subplot(1,2,2)
plt.title('Review count according to neighbourhood')
plt.bar(top_5_neighbourhoods['neighbourhood'],top_5_neighbourhoods['number_of_reviews'])
plt.xlabel('Neighbourhood')
plt.ylabel('Total no. of reviews')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific charts chosen are bar charts representing the number of reviews according to Neighbourhood Groups and Neighbourhoods. Bar charts are suitable for comparing discrete data (number of reviews) across different categories (Neighbourhood Groups and Neighbourhoods). They provide a visual representation of the review count for each category, making it easy to identify patterns and differences.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart showing the number of reviews according to Neighbourhood Groups, the following insights can be derived:
#
#
#
# *   Manhattan and Queens have the highest number of reviews, with 607 and 629 reviews, respectively, making them the most reviewed Neighbourhood Groups.
#
# *   Brooklyn and Staten Island have fewer reviews compared to Manhattan and Queens but still have a significant number of reviews with 488 and 333, respectively.
#
# *   The Bronx has the lowest number of reviews among the provided Neighbourhood Groups, with 321 reviews.
#
# From the bar chart showing the number of reviews according to Neighbourhoods, the following insights can be derived:
#
# *  Jamaica and Harlem have the highest number of reviews among the Neighbourhoods, with 629 and 607 reviews, respectively, making them the most reviewed areas.
#
# *  East Elmhurst and Lower East Side have a substantial number of reviews, with 543 and 540 reviews, respectively.
#
# *   Several Neighbourhoods have very few reviews, and some have zero reviews, indicating that they might be less popular among guests.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar charts can help create a positive business impact:
#
#
# *   Targeted Marketing: Understanding which Neighbourhood Groups and Neighbourhoods have the highest number of reviews allows businesses to focus their marketing efforts on popular areas. They can highlight these areas in their listings and promotions to attract more potential guests.
#
# *   Customer Preferences: Analyzing the number of reviews can provide insights into customer preferences and the popularity of specific areas. Businesses can use this information to curate listings and experiences that align with guests' preferences.
#
# *   Quality Improvements: Monitoring reviews in specific Neighbourhoods with lower review counts can help businesses identify areas that might require improvement in terms of amenities, customer service, or property management.
#
# While the bar charts themselves may not directly lead to negative growth, businesses should consider the following potential challenges:
#
#
#
# *   Competition: Highly reviewed areas might attract more hosts, resulting in increased competition. Businesses should strive to stand out and offer unique value to guests to maintain their competitiveness.
#
# *   Quality Concerns: Neighbourhoods with very few or zero reviews might have low demand or potential issues that deter guests. Businesses should assess the reasons for low review counts and address any quality concerns to improve their offerings.

# %% [markdown]
# ####<h3> 8. Relationship between Price and Number of Reviews

# %%
price_with_reviews = df.groupby(['number_of_reviews'])['price'].max().reset_index()
price_with_reviews.sort_values(by = 'price', ascending = True)
# Out:
#      number_of_reviews  price
# 351                386     29
# 364                411     32
# 322                333     36
# 378                454     39
# 380                459     45
# ..                 ...    ...
# 1                    1   9999
# 6                    6   9999
# 5                    5  10000
# 2                    2  10000
# 0                    0  10000
#
# [394 rows x 2 columns]

# %% [markdown]
# ####<h3> Chart 14 - Scatter plot to show Relationship between Price and Number of Reviews </h3>

# %%
plt.figure(figsize=(12,6))
plt.title('Relationship between Price and Number of Reviews')
plt.scatter(df['price'],df['number_of_reviews'], color ='royalblue')
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a scatter plot representing the relationship between the number of reviews and the price of listings. A scatter plot is suitable for visualizing the relationship between two numerical variables and identifying any patterns or trends. It allows for a quick assessment of how price and the number of reviews are related, making it an effective chart for analyzing correlations between these variables.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  From this scatter plot we can analyze that guests like to go with cheaper price areas and give more number of reviews for those cheaper price areas. As cheaper price areas are affordable so more number of guests go there and as more guest go, they write more reviews for those places more.
#
# From the scatter plot, the following insights can be derived:
#
# *   There is a general positive correlation between the number of reviews and the price of listings. As the price increases, there tends to be a trend of higher numbers of reviews.
#
# *   However, the relationship is not strictly linear. There are instances where higher-priced listings may not necessarily have a significantly larger number of reviews compared to lower-priced listings, and vice versa.
#
# *   There are several outliers in the data. Some listings with very high numbers of reviews have relatively lower prices, while others with very high prices have a lower number of reviews.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the scatter plot can help create a positive business impact:
#
#
#
# *  Pricing Optimization: Understanding the relationship between price and the number of reviews can guide businesses in optimizing their pricing strategies. They can adjust prices to align with customer preferences and expectations, maximizing the number of reviews while maintaining profitability.
#
# *  Competitive Analysis: Analyzing the data can provide insights into competitors' pricing and review counts. Businesses can use this information to position themselves competitively and offer unique value to attract more reviews and guests.
#
# *   Quality Improvements: Identifying outliers and understanding the relationship between price and the number of reviews can highlight areas that may require improvement. Businesses can use feedback from reviews to enhance their offerings, leading to better customer satisfaction and more positive reviews.
#
# While the scatter plot itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
# *   Quality and Price Balance: If high-priced listings do not correspond to a significantly higher number of reviews, it might indicate that customers perceive them as overpriced or not offering sufficient value. This can result in lower demand and negative reviews.
#
# *   Underpriced Listings: Very low-priced listings with a high number of reviews might indicate that the business is not maximizing its revenue potential. Underpricing can lead to missed opportunities for profit.

# %% [markdown]
# ####<h3>9. Minimum nights booking required for accommodation for room type.

# %%
min_nights_data = df.groupby(['minimum_nights'])['room_type'].count().reset_index()
min_nights_data1 = pd.DataFrame(min_nights_data).sort_values(by = 'minimum_nights', ascending = True)
min_nights_data1
# Out:
#      minimum_nights  room_type
# 0                 1      12717
# 1                 2      11693
# 2                 3       7998
# 3                 4       3302
# 4                 5       3033
# ..              ...        ...
# 104             480          1
# 105             500          5
# 106             999          3
# 107            1000          1
# 108            1250          1
#
# [109 rows x 2 columns]

# %% [markdown]
# ####<h3> Chart 15 - Histogram plot for visualization of Minimum nights booking required for accommodation in particular neighbourhood group and room type </h3>

# %%
# Visualization of Minimum nights booking required for accommodation in particular neighbourhood group and room type
plt.figure(figsize=(10, 6))
plt.hist(min_nights_data1['minimum_nights'], bins=30, edgecolor='black')
plt.title('Distribution of Minimum Nights Booking Required for Accommodation')
plt.xlabel('Minimum Nights')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen for visualizing the minimum nights booking required for accommodation in a particular neighborhood group and room type is a histogram plot.
#
# The reason for selecting a histogram plot is because it allows us to visualize the distribution and frequency of values within a continuous or discrete variable (in this case, the minimum nights). It provides a clear representation of how the values are spread across different ranges or bins, making it suitable for analyzing the booking requirements in terms of minimum nights for different accommodations.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The majority of accommodations have a minimum booking requirement between 1 and 10 nights.
#
# *   There is a significant number of accommodations with a minimum booking requirement of 1 or 2 nights.
#
# *  The frequency of accommodations decreases as the minimum nights increase.
#
# *  There are a few accommodations with exceptionally high minimum nights (e.g., around 500, 999, 1000, and 1250), but these are rare outliers.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact of gained insights:
#
# *  The insights from the histogram plot can help businesses understand the typical minimum nights booking requirement for accommodations in different neighborhood groups and room types.
#
# *   This information is valuable for setting pricing strategies, managing availability, and optimizing resources.
#
# *  Businesses can align their marketing and promotion strategies based on the popular booking requirements (e.g., highlighting accommodations with 1 or 2-night minimum stays).
#
# *  By understanding the distribution of minimum nights, businesses can make data-driven decisions to attract and retain customers.
#
# Insights leading to negative growth:
#
# *   From the given data, there are no specific insights that directly indicate negative growth.
#
# *   However, if there were insights suggesting a significant number of accommodations with very high minimum nights, it could potentially lead to negative growth.
#
# *   High minimum night requirements may deter potential customers who prefer shorter stays or more flexible booking options.
#
# *   Businesses should carefully analyze such insights and consider the preferences and needs of their target customers to avoid any negative impact on growth.

# %% [markdown]
# <h5>By analyzing room type and minimum night stay required data, we get following conclusions:
# <h5>1. Minimum nights stay required for booking accommodation ranges from 1 day to 1250 days.
# <h5>2.   Bookings of 1 day minimum is posted by maximum number of hosts as it is be preferable by guests too.
# <h5>3. Frequency of minimum day 1 is more and is decreasing towards more number of minimum days booking.

# %% [markdown]
# ####<h3> 10. Expensiveness in neighbourhoods that is most expensive,average expensive neighbourhoods.

# %%
most_expensive = df.groupby(['neighbourhood'])['price'].max().reset_index()
most_expensive1 = most_expensive.sort_values(by = 'price', ascending = False).head(15)
most_expensive1
# Out:
#           neighbourhood  price
# 202     Upper West Side  10000
# 91           Greenpoint  10000
# 4               Astoria  10000
# 119     Lower East Side   9999
# 61          East Harlem   9999
# 197             Tribeca   8500
# 41         Clinton Hill   8000
# 201     Upper East Side   7703
# 6     Battery Park City   7500
# 60        East Flatbush   7500
# 34              Chelsea   6800
# 92    Greenwich Village   6000
# 115        Little Italy   5250
# 127             Midtown   5100
# 13   Bedford-Stuyvesant   5000

# %%
average_expensive = df.groupby(['neighbourhood'])['price'].mean().reset_index()
average_expensive_min = average_expensive.sort_values(by = 'price', ascending = True).head(10)
average_expensive_min
# Out:
#       neighbourhood      price
# 27      Bull's Head  47.333333
# 102     Hunts Point  50.500000
# 196         Tremont  51.545455
# 179       Soundview  53.466667
# 141        New Dorp  57.000000
# 24        Bronxdale  57.105263
# 142  New Dorp Beach  57.400000
# 88       Grant City  57.666667
# 46          Concord  58.192308
# 135      Mount Eden  58.500000

# %%
average_expensive_max = average_expensive.sort_values(by = 'price', ascending = False).head(10)
average_expensive_max
# Out:
#          neighbourhood       price
# 82      Fort Wadsworth  800.000000
# 219            Woodrow  700.000000
# 197            Tribeca  490.638418
# 174           Sea Gate  487.857143
# 167          Riverdale  442.090909
# 157       Prince's Bay  409.500000
# 6    Battery Park City  367.557143
# 75   Flatiron District  341.925000
# 161      Randall Manor  336.000000
# 144               NoHo  295.717949

# %%
overall_average = df['price'].mean()
overall_average
# Out:
# 152.75505277800508

# %% [markdown]
# ####<h3> Chart 16 - Scatter plot for visualization of most expensive neighbourhood </h3>

# %%
plt.figure(figsize=(15, 6))
most_expensive2 = most_expensive.head(40)
plt.scatter(most_expensive2['neighbourhood'], most_expensive2['price'],color='purple')
plt.xlabel('Neighbourhood')
plt.ylabel('Price')
plt.title('Most Expensive Neighbourhoods')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a scatter plot representing the most expensive neighbourhoods along with their corresponding prices. A scatter plot is suitable for visualizing the relationship between two numerical variables, in this case, neighbourhoods and prices. It allows for a clear display of individual data points and their values, making it effective for identifying patterns and outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot, the following insights can be derived:
#
# *  The scatter plot highlights the most expensive neighbourhoods and their respective price points.
#
# *   Upper West Side, Greenpoint, and Astoria are the most expensive neighbourhoods, each with a price of $10,000.
#
# *   There is a range of prices among the most expensive neighbourhoods, with some areas having slightly lower prices such as Tribeca at 8,500 and Clinton Hill at 8,000.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the scatter plot can help create a positive business impact:
#
# *   Pricing Strategy: Understanding the most expensive neighbourhoods allows businesses to tailor their pricing strategies for those specific areas. They can offer premium services or amenities to cater to high-end travellers looking for luxury accommodations.
#
# *  Marketing Focus: Businesses can use this information to focus their marketing efforts on the most expensive neighbourhoods. They can highlight these areas in their promotional materials to attract guests who are willing to pay a premium for exclusive locations.
#
# *  Targeted Offerings: Businesses can create specialized packages or experiences for the most expensive neighbourhoods to provide unique value to guests and justify the higher prices.
#
# While the scatter plot itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
# *   Overemphasis on High Prices: Focusing solely on the most expensive neighbourhoods might lead to neglecting other potentially profitable areas. Diversifying offerings across different price ranges and neighbourhoods can help avoid missing out on a broader customer base.
#
# *  Quality Consistency: High prices in certain neighbourhoods might lead to higher guest expectations. If the quality of accommodations or services does not match the premium price, it can lead to negative reviews and reduced repeat bookings.

# %% [markdown]
# ####<h3> Chart 17 - Bar and line plot for visualization of Minimum Average, Maximum Average, and Overall Average Expensive Neighbourhoods

# %%
# Visualization of Minimum Average, Maximum Average, and Overall Average Expensive Neighbourhoods
average_expensive_min1 = average_expensive_min.head(15)
average_expensive_max1 = average_expensive_max.head(15)

plt.figure(figsize=(15, 6))
plt.bar(average_expensive_min1['neighbourhood'], average_expensive_min1['price'], color='red', label='Least Expensive')
plt.bar(average_expensive_max1['neighbourhood'], average_expensive_max1['price'], color='green', label='Most Expensive')
plt.axhline(overall_average, color='blue', linestyle='dashed', linewidth=2, label='Overall Average')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.title('Minimum Average, Maximum Average, and Overall Average Expensive Neighbourhoods')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a combination of bar and line plots. Bar plots are used to represent the minimum and maximum average prices in the most expensive neighbourhoods, while a line plot is used to represent the overall average price. This combination of plots is suitable for comparing different aspects of average prices across neighbourhoods in a visually clear and concise manner.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the combined bar and line plot, the following insights can be derived:
#
#
# *  The bar plot for the minimum average prices shows the neighbourhoods with the lowest average prices among the most expensive neighbourhoods. These neighbourhoods, such as Bull's Head, Hunts Point, and Tremont, have relatively lower average prices compared to others.
#
# *  The bar plot for the maximum average prices highlights the most expensive neighbourhoods, such as Fort Wadsworth, Woodrow, and Tribeca, which have significantly higher average prices.
#
# *   The line plot represents the overall average price, which serves as a reference point. It indicates that the majority of neighbourhoods fall within the range of the overall average price (around $152.76).

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the combined plot can help create a positive business impact:
#
# *   Pricing Strategy: Understanding the range of average prices among the most expensive neighbourhoods allows businesses to adjust their pricing strategies. They can set competitive prices that align with the local market and the preferences of travellers looking for luxury accommodations or budget-friendly options.
#
# *   Targeted Marketing: Businesses can use the insights to tailor their marketing efforts. For example, they can promote neighbourhoods with lower average prices to budget-conscious travellers and emphasize luxury features for neighbourhoods with higher average prices.
#
# *   Revenue Optimization: By considering the minimum and maximum average prices alongside the overall average, businesses can optimize their revenue by strategically pricing different neighbourhoods based on demand and customer expectations.
#
#
#
#
#
# While the combined plot itself may not directly lead to negative growth, businesses should consider the following potential challenges:
#
# *   Price Perception: Neighbourhoods with significantly lower average prices might be perceived as lower in quality, potentially leading to reduced demand and negative reviews.
#
# * Overpriced Listings: Neighbourhoods with extremely high average prices might deter potential guests if the value does not match the price. This can lead to lower occupancy rates and negative feedback.

# %% [markdown]
# ####<h3> 11. Host IDs with Highest Number of Calculated Host Listings Count

# %%
host_listing_count = df.groupby(['host_id'])['calculated_host_listings_count'].count().reset_index()
host_listing= host_listing_count.sort_values(by = 'calculated_host_listings_count', ascending = False).head(10)
host_listing
# Out:
#          host_id  calculated_host_listings_count
# 34644  219517861                             327
# 29405  107434423                             232
# 19572   30283594                             121
# 31077  137358866                             103
# 14434   16098958                              96
# 12805   12243051                              96
# 25660   61391963                              91
# 17089   22541573                              87
# 33866  200380610                              65
# 9732     7503643                              52

# %% [markdown]
# ####<h3> Chart 18 - Bar chart to show top 10 Host IDs with Highest Number of Calculated Host Listings Count</h3>

# %%
plt.figure(figsize=(12, 6))
plt.bar(range(len(host_listing)), host_listing['calculated_host_listings_count'], color='slateblue')
plt.xticks(range(len(host_listing)), host_listing['host_id'], rotation=45, ha='right')
plt.xlabel('Host ID')
plt.ylabel('Number of Calculated Host Listings Count')
plt.title('Top 10 Host IDs with Highest Number of Calculated Host Listings Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing the top 10 Host IDs with the highest number of calculated host listings count. A bar chart is an appropriate choice to visualize and compare the number of listings for different host IDs. It provides a clear and easy-to-understand visual representation of the data, making it effective for identifying the hosts with the most listings.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, the following insights can be derived:
#
#
# *   Host ID 219517861 has the highest calculated host listings count with 327 listings.
#
# *  The top 10 hosts listed in the chart have a significant number of listings, ranging from 52 to 327 listings.
#
# *  There might be a concentration of professional hosts or property management companies among the top hosts, as they tend to manage multiple listings.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart can help create a positive business impact:
#
# *   Host Relationship: Understanding which hosts have the highest number of listings allows businesses to build stronger relationships with these hosts. Providing them with exceptional support, exclusive offers, or additional marketing exposure can incentivize them to continue listing their properties.
#
# *   Inventory Management: Businesses can use this information to manage their inventory and ensure a diverse range of listings. They can work with top hosts to optimize their listings, update content, and maintain competitive pricing.
#
# *   Guest Experience: For hosts with multiple listings, providing consistent and high-quality guest experiences across all properties is crucial. Businesses can collaborate with these hosts to ensure that guests receive excellent service, leading to positive reviews and repeat bookings.
#
# While the bar chart itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
# *   Dependency on Few Hosts: Relying heavily on a few hosts with a large number of listings might lead to reduced diversity in inventory. If these hosts decide to discontinue their listings or reduce their involvement, it could impact the overall number of available properties.
#
# *  Quality Control: Hosts with a large number of listings might struggle to maintain consistent quality across all properties. If guests have negative experiences in multiple listings from the same host, it could lead to negative reviews and reduced bookings.

# %% [markdown]
# ####<h3>12. Neighborhoods with the Highest Number of Hosts listings

# %%
host_listing_count = df.groupby(['neighbourhood'])['calculated_host_listings_count'].count().reset_index()
top_host = host_listing_count.sort_values(by = 'calculated_host_listings_count', ascending = False).head(10)
top_host
# Out:
#           neighbourhood  calculated_host_listings_count
# 214        Williamsburg                            3919
# 13   Bedford-Stuyvesant                            3710
# 94               Harlem                            2658
# 28             Bushwick                            2462
# 202     Upper West Side                            1971
# 95       Hell's Kitchen                            1958
# 64         East Village                            1853
# 201     Upper East Side                            1798
# 51        Crown Heights                            1564
# 127             Midtown                            1545

# %% [markdown]
# ####<h3> Chart 19 - Bar chart to show Neighborhoods with the Highest Number of Hosts listings

# %%
top_host = host_listing_count.sort_values(by='calculated_host_listings_count', ascending=False).head(10)

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(top_host['neighbourhood'], top_host['calculated_host_listings_count'], color='skyblue')
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Unique Hosts')
plt.title('Top 10 Neighborhoods with the Highest Number of Unique Hosts')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart representing neighborhoods with the highest number of host listings. A bar chart is an appropriate choice for visualizing and comparing the number of host listings in different neighborhoods. It provides a clear and straightforward way to showcase the distribution of host listings across various areas.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart, the following insights can be derived:
#
#
# *   Williamsburg and Bedford-Stuyvesant are the neighborhoods with the highest number of host listings, with 3919 and 3710 listings, respectively.
#
# *   Harlem, Bushwick, Upper West Side, and Hell's Kitchen also have a significant number of host listings, each with over 1950 listings.
#
# *  The top neighborhoods with the highest number of host listings are distributed across different parts of the city, indicating a diverse range of hosting activity.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the bar chart can help create a positive business impact:
#
# *   Targeted Marketing: Businesses can tailor their marketing efforts to focus on neighborhoods with the highest number of host listings. They can promote these areas to potential guests, showcasing the variety of accommodations and experiences available.
#
# *  Inventory Management: Understanding which neighborhoods have the highest number of host listings allows businesses to strategically manage their inventory. They can ensure a balanced distribution of listings across neighborhoods, avoiding over-saturation in certain areas and maintaining a competitive edge.
#
# *  Host Engagement: Businesses can engage with hosts in neighborhoods with the highest listings to strengthen relationships. Offering additional support, exclusive partnerships, or incentives can encourage hosts to continue listing their properties.
#
# While the bar chart itself may not directly lead to negative growth, there are potential challenges to consider:
#
#
# *  Competition and Oversaturation: High numbers of host listings in specific neighborhoods can lead to increased competition among hosts. This may result in price wars, reduced profitability, and challenges in standing out from other listings.
#
# *  Quality Control: In neighborhoods with high host activity, ensuring consistent quality and guest experiences across all listings can be a challenge. Negative experiences in a particular neighborhood can lead to reduced demand and negative reviews.

# %% [markdown]
# #### Chart - 20 - Correlation Heatmap

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Correlation Heatmap visualization code
selected_columns = df[['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']]

# Calculate the correlation matrix for the selected columns
correlation_matrix = selected_columns.corr()

# Plot the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a correlation heatmap. A correlation heatmap is a suitable choice for visualizing the relationships and correlations between multiple numerical variables. It provides a comprehensive overview of how variables are related to each other, helping to identify patterns, dependencies, and potential multicollinearity.
#
# Overall, the heatmap helps in understanding how different features in the dataset are interrelated, which can guide data analysis, model building, and business decisions. It can also provide insights into potential areas for further investigation or feature engineering.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the correlation heatmap, the following insights can be derived:
#
#
# *   Price and Availability: There is a positive correlation between the 'price' of a listing and its 'availability_365', indicating that higher-priced listings tend to be available for more days.
#
# *   Number of Reviews and Reviews per Month: The 'number_of_reviews' and 'reviews_per_month' have a positive correlation, which suggests that listings with more reviews tend to have a higher monthly review rate.
#
# *   Host Listings and Reviews: There is a positive correlation between 'calculated_host_listings_count' and 'number_of_reviews', indicating that hosts with more listings tend to have more reviews.
#
# *   Minimum Nights and Reviews per Month: There is a slight negative correlation between 'minimum_nights' and 'reviews_per_month', suggesting that listings with longer minimum stay requirements may receive fewer reviews per month.
#
# *  Latitude and Longitude: The 'latitude' and 'longitude' values are not strongly correlated with other variables, indicating that these geographic coordinates are relatively independent of the other factors.
#
#
#
# The correlation coefficients provide a quantitative measure of the strength and direction of these relationships. Positive correlations indicate that as one variable increases, the other tends to increase as well, while negative correlations indicate that as one variable increases, the other tends to decrease.

# %% [markdown]
# #### Chart - 21 - Pair Plot

# %%
# Pair Plot visualization code
# Select columns for pair plot
pair_columns = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# Create pair plot
sns.pairplot(df[pair_columns])
plt.suptitle('Pair Plot of Selected Variables', y=1.02)
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a pair plot. A pair plot is selected for its ability to visualize pairwise relationships and correlations between multiple numerical variables in a single grid of scatterplots. This makes it easy to explore the interactions between variables and identify potential patterns, trends, and outliers.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Correlations: Strong positive correlations between two variables are indicated by the points in the scatterplots forming an upward-sloping pattern. Strong negative correlations are indicated by a downward-sloping pattern. For instance, you can examine whether there is a relationship between 'number_of_reviews' and 'reviews_per_month', or between 'calculated_host_listings_count' and 'availability_365'.
#
# *   Outliers: Outliers, which are data points that significantly deviate from the overall pattern, can be identified in the scatterplots. For example, if you notice a few data points far from the main cluster in a scatterplot, it could indicate potential outliers that warrant further investigation.
#
# Overall, the pair plot provides a comprehensive visual exploration of the dataset, allowing to gain a deeper understanding of how variables are related and potentially guiding further analysis and decision-making. It can help identify potential areas for more focused investigation and provide a foundation for building data-driven insights and strategies.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To help the client achieve their business objectives based on the Airbnb booking analysis dataset, I would suggest the following strategies:
#
# 1.   Implement dynamic pricing models that consider factors like seasonality, demand, local events, and competitor pricing.
#
# 2.   Encourage hosts to provide exceptional guest experiences through clear communication, well-maintained properties, and thoughtful amenities.
#
# 3.  Offer personalized recommendations to guests based on their preferences and booking history to enhance their overall stay.
#
# 4.   Allocate resources to manage inventory effectively, focusing on high-demand areas to maximize occupancy and revenue.
#
# 5.   Collaborate with hosts to create appealing promotional packages or exclusive offers for guests.
#
# 6.  Leverage social media and online platforms to showcase listings, neighborhoods, and positive guest experiences.
#
# 7.   Regularly audit listings to address any discrepancies between advertised amenities and the actual guest experience.
#
# 8.   Collaborate with local businesses and organizations to offer guests unique experiences and services, contributing to a positive and memorable stay.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.	The histogram reveals the concentration of prices within the range of 10 to 2000. As the majority of prices are clustered in this range, it indicates that most listings fall within this price bracket.
#
# 2.	The most common room type is "Entire home/apt" indicating a high demand for entire homes or apartments as accommodations.The second most common room type is "Private room that still in substantial demand.The least common room type is "Shared room" indicating limited interest in shared accommodations. Moreover, the count for shared rooms is closer to 0, suggesting a relatively low demand for this room type.
#
# 3.	Manhattan and Brooklyn are the most popular Neighbourhood Groups, Queens has a moderate popularity, Bronx and Staten Island have lower popularity compared to the other three, suggesting that they might attract fewer Airbnb guests.
#
# 4.	The most expensive listings in both Brooklyn and Manhattan are "Entire home/apt" type, with a price of 10,000. These two Neighbourhood Groups have premium offerings for entire homes or apartments.
#
# 5.	Queens has the most expensive "Private room" listing, priced at 10,000.
#
# 6.	The highest-priced "Entire home/apt" in Queens is 2,600, indicating that Queens offers a range of entire home accommodations at more affordable prices.
#
# 7.	Manhattan has the highest average prices across all room types, indicating that it is generally the most expensive Neighbourhood Group for accommodations.
#
# 8.	Entire homes or apartments are the most expensive listings among the three room types. Private rooms are generally more affordable for guests.The "Shared room" category offers the most budget-friendly accommodation option among the three room types.
#
# 9.	Manhattan and Queens have the highest number of reviews  making them the most reviewed Neighbourhood Groups. The Bronx has
# the lowest number of reviews among the provided Neighbourhood Groups.
#
# 10.	Jamaica and Harlem have the highest number of reviews among the Neighbourhoods making them the most reviewed areas.
#
# 11.	There is a general positive correlation between the number of reviews and the price of listings. As the price increases, there tends to be a trend of higher numbers of reviews.
#
# 12.	The frequency of accommodations decreases as the minimum nights increase.
#
# 13.	Upper West Side, Greenpoint, and Astoria are the most expensive neighbourhoods.
#
# 14.	Bull's Head, Hunts Point, and Tremont, have relatively lower average prices.Fort Wadsworth, Woodrow, and Tribeca have significantly higher average prices.
#
# 15.	Host ID 219517861 has the highest calculated host listings count with 327 listings and the top 10 hosts listed have a significant number of listings, ranging from 52 to 327 listings.
#
# 16.	Williamsburg and Bedford-Stuyvesant are the neighborhoods with the highest number of host listings, Harlem, Bushwick, Upper West Side, and Hell's Kitchen also have a significant number of host listings  indicating a diverse range of hosting activity.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
